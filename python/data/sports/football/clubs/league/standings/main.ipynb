# %%
import pandas

# %%
file_name = "./datasets.csv"

# %%
standings_data_frame = pandas.read_csv(file_name)
standings_data_frame = standings_data_frame.sort_values(
    by=["country", "competition_tier", "competition", "season"]
)
standings_data_frame.to_csv(file_name, index=False)
standings_data_frame
# Out:
#            country  competition_tier          competition     season  \
# 0          England                 1       Premier League  1992-1993
# 1          England                 1       Premier League  1993-1994
# 2          England                 1       Premier League  1994-1995
# 3          England                 1       Premier League  1995-1996
# 4          England                 1       Premier League  1996-1997
# ..             ...               ...                  ...        ...
# 612  United States                 1  Major League Soccer       2018
# 613  United States                 1  Major League Soccer       2019
# 614  United States                 1  Major League Soccer       2020
# 615  United States                 1  Major League Soccer       2021
# 616  United States                 1  Major League Soccer       2022
#
#                    champion champion_former  champion_point  \
# 0         Manchester United             NaN             NaN
# ...

# %%
competitions = standings_data_frame["competition"].unique()
competitions
# Out:
# array(['Premier League', 'English Football League - Championship',
#        'English Football League - League One',
#        'English Football League - League Two', 'National League',
#        'National League North', 'National League South', 'Ligue 1',
#        'Bundesliga', 'Seria A', 'J1 League', 'K League 1', 'K League 2',
#        'Eredivisie', 'Primeira Liga', 'Singapore Premier League',
#        'La Liga', 'Major League Soccer'], dtype=object)

# %% [markdown]
# ## Premier League

# %%
premier_league_data_frame = standings_data_frame[
    standings_data_frame["competition"] == "Premier League"
]
premier_league_data_frame
# Out:
#     country  competition_tier     competition     season           champion  \
# 0   England                 1  Premier League  1992-1993  Manchester United
# 1   England                 1  Premier League  1993-1994  Manchester United
# 2   England                 1  Premier League  1994-1995   Blackburn Rovers
# 3   England                 1  Premier League  1995-1996  Manchester United
# 4   England                 1  Premier League  1996-1997  Manchester United
# 5   England                 1  Premier League  1997-1998            Arsenal
# 6   England                 1  Premier League  1998-1999  Manchester United
# 7   England                 1  Premier League  1999-2000  Manchester United
# 8   England                 1  Premier League  2000-2001  Manchester United
# 9   England                 1  Premier League  2001-2002            Arsenal
# 10  England                 1  Premier League  2002-2003  Manchester United
# ...

# %%
champions = premier_league_data_frame["champion"].value_counts()
champions
# Out:
# champion
# Manchester United    13
# Manchester City       7
# Chelsea               5
# Arsenal               3
# Blackburn Rovers      1
# Leicester City        1
# Liverpool             1
# Name: count, dtype: int64

# %%
runners_up = premier_league_data_frame["runner_up"].value_counts()
runners_up
# Out:
# runner_up
# Manchester United    7
# Arsenal              7
# Liverpool            5
# Chelsea              4
# Manchester City      3
# Newcastle United     2
# Aston Villa          1
# Blackburn Rovers     1
# Tottenham Hotspur    1
# Name: count, dtype: int64

# %%
third_places = premier_league_data_frame["third_place"].value_counts()
third_places
# Out:
# third_place
# Liverpool             6
# Chelsea               6
# Arsenal               5
# Manchester United     5
# Newcastle United      2
# Tottenham Hotspur     2
# Norwich City          1
# Nottingham Forrest    1
# Leeds United          1
# Manchester City       1
# Name: count, dtype: int64

# %%
fourth_places = premier_league_data_frame["fourth_place"].value_counts()
fourth_places
# Out:
# fourth_place
# Liverpool            7
# Arsenal              6
# Chelsea              5
# Tottenham Hotspur    3
# Leeds United         2
# Newcastle United     2
# Manchester City      2
# Blackburn Rovers     1
# Aston Villa          1
# Everton              1
# Manchester United    1
# Name: count, dtype: int64
