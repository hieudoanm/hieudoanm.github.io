# %%
import os
import json

folders = [f.path for f in os.scandir(".") if f.is_dir()]
folders.sort()

for folder in folders:
    files = [f.path for f in os.scandir(f"{folder}/json") if f.is_file()]
    all = list()
    for file in files:
        if "all" in file:
            continue
        in_file = open(file, "r")
        all.extend(json.load(in_file))
        in_file.close()
    all_json = open(f"{folder}/json/all.json", "w")
    all_json.write(json.dumps(all, indent=4))
    all_json.close()
    print(folder, "{:,}".format(len(all)))
# Out:
# ./anishgiri 1,429
# ./azerichess 3,760
# ./chefshouse 595
# ./chesswarrior7197 6,154
# ./danielnaroditsky 110,603
# ./denlaz 6,177
# ./dominguezonyoutube 4,349
# ./duhless 14,590
# ./fabianocaruana 4,605
# ./firouzja2003 35,060
# ./ghandeevam2003 35,469
# ./gmwso 9,557
# ./grischuk 4,458
# ./gukeshdommaraju 5,642
# ./hikaru 57,752
# ./lachesisq 7,177
# ./levonaronian 1,058
# ./liemle 2,851
# ./lyonbeast 5,372
# ./magnuscarlsen 5,217
# ./penguingm1 42,862
# ./polish_fighter3000 12,165
# ./rpragchess 8,604
# ./sergeykarjakin 489
# ./thevish 66
# ./tradjabov 1,343
# ./veselintopalov359 25
# ./viditchess 3,631
# ./vincentkeymer 10,992
# ./vladimirkramnik 2,113
# ./wonderfultime 59,423
