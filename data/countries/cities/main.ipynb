# %% [markdown]
# # Cities

# %%
import pandas

# %%
cities_data_frame = pandas.read_csv("./cities.csv")
cities_data_frame
# Out:
#        country       city     province_state    region           subregion  \
# 0    Australia     Sydney    New South Wales       NaN                 NaN
# 1    Australia  Melbourne           Victoria       NaN                 NaN
# 2    Australia   Brisbane         Queensland       NaN                 NaN
# 3    Australia      Perth  Western Australia       NaN                 NaN
# 4    Australia   Adelaide    South Australia       NaN                 NaN
# ..         ...        ...                ...       ...                 ...
# 311    Vietnam  Sóc Trăng          Sóc Trăng  Southern  Mekong River Delta
# 312    Vietnam     Mỹ Tho         Tiền Giang  Southern  Mekong River Delta
# 313    Vietnam   Trà Vinh           Trà Vinh  Southern  Mekong River Delta
# 314    Vietnam  Vĩnh Long          Vĩnh Long  Southern  Mekong River Delta
# 315    Vietnam    Cần Thơ            Cần Thơ  Southern  Mekong River Delta
#
#     province_state_level
# 0                  state
# ...

# %%
countries = cities_data_frame["country"].unique()
countries.sort()
print(len(countries))
countries
# Out:
# 10
# array(['Australia', 'England', 'France', 'Germany', 'Italy',
#        'Netherlands', 'New Zealand', 'Spain', 'United States', 'Vietnam'],
#       dtype=object)

# %% [markdown]
# ## Australia

# %%
australia_data_frame = cities_data_frame[cities_data_frame["country"] == "Australia"]
australia_data_frame
# Out:
#      country       city                province_state region subregion  \
# 0  Australia     Sydney               New South Wales    NaN       NaN
# 1  Australia  Melbourne                      Victoria    NaN       NaN
# 2  Australia   Brisbane                    Queensland    NaN       NaN
# 3  Australia      Perth             Western Australia    NaN       NaN
# 4  Australia   Adelaide               South Australia    NaN       NaN
# 5  Australia     Hobart                      Tasmania    NaN       NaN
# 6  Australia   Canberra  Australian Capital Territory    NaN       NaN
# 7  Australia     Darwin            Northern Territory    NaN       NaN
#
#   province_state_level
# 0                state
# 1                state
# 2                state
# 3                state
# 4                state
# 5                state
# 6            territory
# 7            territory

# %%
states = australia_data_frame["province_state"].unique()
states.sort()
print(len(states))
states
# Out:
# 8
# array(['Australian Capital Territory', 'New South Wales',
#        'Northern Territory', 'Queensland', 'South Australia', 'Tasmania',
#        'Victoria', 'Western Australia'], dtype=object)

# %% [markdown]
# ## England

# %%
england_data_frame = cities_data_frame[cities_data_frame["country"] == "England"]
england_data_frame
# Out:
#     country                 city            province_state  \
# 8   England              Reading                 Berkshire
# 9   England        Milton Keynes           Buckinghamshire
# 10  England             Brighton               East Sussex
# 11  England          Southampton                 Hampshire
# 12  England           Portsmouth                 Hampshire
# 13  England              Newport             Isle of Wight
# 14  England            Maidstone                      Kent
# 15  England               Oxford               Oxfordshire
# 16  England            Guildford                    Surrey
# 17  England              Crawley               West Sussex
# 18  England       City of London            City of London
# 19  England               London            Greater London
# 20  England           Warrington                  Cheshire
# 21  England             Carlisle                   Cumbria
# 22  England           Manchester        Greater Manchester
# ...

# %%
counties = england_data_frame["province_state"].unique()
counties.sort()
print(len(counties))
counties
# Out:
# 48
# array(['Bedfordshire', 'Berkshire', 'Bristol', 'Buckinghamshire',
#        'Cambridgeshire', 'Cheshire', 'City of London', 'Cornwall',
#        'County Durham', 'Cumbria', 'Derbyshire', 'Devon', 'Dorset',
#        'East Riding of Yorkshire', 'East Sussex', 'Essex',
#        'Gloucestershire', 'Greater London', 'Greater Manchester',
#        'Hampshire', 'Herefordshire', 'Hertfordshire', 'Isle of Wight',
#        'Kent', 'Lancashire', 'Leicestershire', 'Lincolnshire',
#        'Merseyside', 'Norfolk', 'North Yorkshire', 'Northamptonshire',
#        'Northumberland', 'Nottinghamshire', 'Oxfordshire', 'Rutland',
#        'Shropshire', 'Somerset', 'South Yorkshire', 'Staffordshire',
#        'Suffolk', 'Surrey', 'Tyne and Wear', 'Warwickshire',
#        'West Midlands', 'West Sussex', 'West Yorkshire', 'Wiltshire',
#        'Worcestershire'], dtype=object)

# %% [markdown]
# ## France

# %%
france_data_frame = cities_data_frame[cities_data_frame["country"] == "France"]
france_data_frame
# Out:
#    country            city              province_state region subregion  \
# 60  France            Lyon        Auvergne-Rhône-Alpes    NaN       NaN
# 61  France           Dijon     Bourgogne-Franche-Comté    NaN       NaN
# 62  France          Rennes                    Bretagne    NaN       NaN
# 63  France         Orléans         Centre-Val de Loire    NaN       NaN
# 64  France         Ajaccio                       Corse    NaN       NaN
# 65  France      Strasbourg                   Grand Est    NaN       NaN
# 66  France           Lille             Hauts-de-France    NaN       NaN
# 67  France           Paris               Île-de-France    NaN       NaN
# 68  France           Rouen                   Normandie    NaN       NaN
# 69  France        Bordeaux          Nouvelle-Aquitaine    NaN       NaN
# 70  France        Toulouse                   Occitanie    NaN       NaN
# 71  France          Nantes            Pays de la Loire    NaN       NaN
# ...

# %%
regions = france_data_frame["province_state"].unique()
regions.sort()
print(len(regions))
regions
# Out:
# 18
# array(['Auvergne-Rhône-Alpes', 'Bourgogne-Franche-Comté', 'Bretagne',
#        'Centre-Val de Loire', 'Corse', 'Grand Est', 'Guadeloupe',
#        'Guyane', 'Hauts-de-France', 'La Réunion', 'Martinique', 'Mayotte',
#        'Normandie', 'Nouvelle-Aquitaine', 'Occitanie', 'Pays de la Loire',
#        "Provence-Alpes-Côte d'Azur", 'Île-de-France'], dtype=object)

# %% [markdown]
# ## Germany

# %%
germany_data_frame = cities_data_frame[cities_data_frame["country"] == "Germany"]
germany_data_frame
# Out:
#     country               city          province_state region subregion  \
# 78  Germany             Berlin                  Berlin   East       NaN
# 79  Germany           Schwerin  Mecklenburg-Vorpommern   East       NaN
# 80  Germany            Dresden                  Saxony   East       NaN
# 81  Germany          Magdeburg           Saxony-Anhalt   East       NaN
# 82  Germany             Erfurt               Thuringia   East       NaN
# 83  Germany            Potsdam             Brandenburg   East       NaN
# 84  Germany          Stuttgart       Baden-Württemberg   West       NaN
# 85  Germany             Munich                 Bavaria   West       NaN
# 86  Germany             Bremen                  Bremen   West       NaN
# 87  Germany            Hamburg                 Hamburg   West       NaN
# 88  Germany          Wiesbaden                   Hesse   West       NaN
# 89  Germany  Frankfurt am Main                   Hesse   West       NaN
# ...

# %%
states = germany_data_frame["province_state"].unique()
states.sort()
print(len(states))
states
# Out:
# 16
# array(['Baden-Württemberg', 'Bavaria', 'Berlin', 'Brandenburg', 'Bremen',
#        'Hamburg', 'Hesse', 'Lower Saxony', 'Mecklenburg-Vorpommern',
#        'North Rhine-Westphalia', 'Rhineland-Palatinate', 'Saarland',
#        'Saxony', 'Saxony-Anhalt', 'Schleswig-Holstein', 'Thuringia'],
#       dtype=object)

# %% [markdown]
# ## Italy

# %%
italy_data_frame = cities_data_frame[cities_data_frame["country"] == "Italy"]
italy_data_frame
# Out:
#     country        city         province_state region subregion  \
# 96    Italy    L'Aquila                Abruzzo    NaN       NaN
# 97    Italy       Aosta           Aosta Valley    NaN       NaN
# 98    Italy        Bari                 Apulia    NaN       NaN
# 99    Italy     Potenza             Basilicata    NaN       NaN
# 100   Italy   Catanzaro               Calabria    NaN       NaN
# 101   Italy      Naples               Campania    NaN       NaN
# 102   Italy     Bologna         Emilia-Romagna    NaN       NaN
# 103   Italy     Trieste  Friuli-Venezia Giulia    NaN       NaN
# 104   Italy        Rome                  Lazio    NaN       NaN
# 105   Italy       Genoa                Liguria    NaN       NaN
# 106   Italy       Milan               Lombardy    NaN       NaN
# 107   Italy      Ancona                 Marche    NaN       NaN
# 108   Italy  Campobasso                 Molise    NaN       NaN
# 109   Italy       Turin               Piedmont    NaN       NaN
# ...

# %%
regions = italy_data_frame["province_state"].unique()
regions.sort()
print(len(regions))
regions
# Out:
# 20
# array(['Abruzzo', 'Aosta Valley', 'Apulia', 'Basilicata', 'Calabria',
#        'Campania', 'Emilia-Romagna', 'Friuli-Venezia Giulia', 'Lazio',
#        'Liguria', 'Lombardy', 'Marche', 'Molise', 'Piedmont', 'Sardinia',
#        'Sicily', 'Trentino-South Tyrol', 'Tuscany', 'Umbria', 'Veneto'],
#       dtype=object)

# %% [markdown]
# ## Netherlands

# %%
netherlands_data_frame = cities_data_frame[
    cities_data_frame["country"] == "Netherlands"
]
netherlands_data_frame
# Out:
#          country              city province_state region subregion  \
# 116  Netherlands             Assen        Drenthe    NaN       NaN
# 117  Netherlands             Emmen        Drenthe    NaN       NaN
# 118  Netherlands          Lelystad      Flevoland    NaN       NaN
# 119  Netherlands            Almere      Flevoland    NaN       NaN
# 120  Netherlands        Leeuwarden      Friesland    NaN       NaN
# 121  Netherlands            Arnhem     Gelderland    NaN       NaN
# 122  Netherlands          Nijmegen     Gelderland    NaN       NaN
# 123  Netherlands         Groningen      Groningen    NaN       NaN
# 124  Netherlands        Maastricht        Limburg    NaN       NaN
# 125  Netherlands  's-Hertogenbosch  North Brabant    NaN       NaN
# 126  Netherlands         Eindhoven      Eindhoven    NaN       NaN
# 127  Netherlands           Haarlem  North Holland    NaN       NaN
# 128  Netherlands         Amsterdam  North Holland    NaN       NaN
# ...

# %%
provinces = italy_data_frame["province_state"].unique()
provinces.sort()
print(len(provinces))
provinces
# Out:
# 20
# array(['Abruzzo', 'Aosta Valley', 'Apulia', 'Basilicata', 'Calabria',
#        'Campania', 'Emilia-Romagna', 'Friuli-Venezia Giulia', 'Lazio',
#        'Liguria', 'Lombardy', 'Marche', 'Molise', 'Piedmont', 'Sardinia',
#        'Sicily', 'Trentino-South Tyrol', 'Tuscany', 'Umbria', 'Veneto'],
#       dtype=object)

# %% [markdown]
# ## New Zealand

# %%
new_zealand_data_frame = cities_data_frame[
    cities_data_frame["country"] == "New Zealand"
]
new_zealand_data_frame
# Out:
#          country              city      province_state region subregion  \
# 136  New Zealand         Whangārei           Northland  North       NaN
# 137  New Zealand          Auckland            Auckland  North       NaN
# 138  New Zealand          Hamilton             Waikato  North       NaN
# 139  New Zealand         Whakatāne       Bay of Plenty  North       NaN
# 140  New Zealand          Gisborne            Gisborne  North       NaN
# 141  New Zealand            Napier         Hawke's Bay  North       NaN
# 142  New Zealand         Stratford            Taranaki  North       NaN
# 143  New Zealand  Palmerston North  Manawatū-Whanganui  North       NaN
# 144  New Zealand        Wellington          Wellington  North       NaN
# 145  New Zealand          Richmond              Tasman  South       NaN
# 146  New Zealand            Nelson              Nelson  South       NaN
# 147  New Zealand          Blenheim         Marlborough  South       NaN
# ...

# %%
regions = new_zealand_data_frame["province_state"].unique()
regions.sort()
print(len(regions))
regions
# Out:
# 16
# array(['Auckland', 'Bay of Plenty', 'Canterbury', 'Gisborne',
#        "Hawke's Bay", 'Manawatū-Whanganui', 'Marlborough', 'Nelson',
#        'Northland', 'Otago', 'Southland', 'Taranaki', 'Tasman', 'Waikato',
#        'Wellington', 'West Coast'], dtype=object)

# %% [markdown]
# ## Spain

# %%
spain_data_frame = cities_data_frame[cities_data_frame["country"] == "Spain"]
spain_data_frame
# Out:
#     country                    city      province_state region subregion  \
# 152   Spain                 Seville           Andalusia    NaN       NaN
# 153   Spain                Zaragoza              Aragon    NaN       NaN
# 154   Spain                  Oviedo            Asturias    NaN       NaN
# 155   Spain                   Palma    Balearic Islands    NaN       NaN
# 156   Spain         Vitoria-Gasteiz      Basque Country    NaN       NaN
# 157   Spain              Las Palmas      Canary Islands    NaN       NaN
# 158   Spain              Santa Cruz      Canary Islands    NaN       NaN
# 159   Spain               Santander           Cantabria    NaN       NaN
# 160   Spain              Valladolid    Castile and León    NaN       NaN
# 161   Spain                  Toledo  Castilla–La Mancha    NaN       NaN
# 162   Spain               Barcelona           Catalonia    NaN       NaN
# 163   Spain                  Mérida         Extremadura    NaN       NaN
# ...

# %%
communities = spain_data_frame["province_state"].unique()
communities.sort()
print(len(communities))
communities
# Out:
# 17
# array(['Andalusia', 'Aragon', 'Asturias', 'Balearic Islands',
#        'Basque Country', 'Canary Islands', 'Cantabria',
#        'Castile and León', 'Castilla–La Mancha', 'Catalonia',
#        'Extremadura', 'Galicia', 'La Rioja', 'Madrid', 'Murcia',
#        'Navarre', 'Valencia'], dtype=object)

# %% [markdown]
# ## United States

# %%
united_states_data_frame = cities_data_frame[
    cities_data_frame["country"] == "United States"
]
united_states_data_frame
# Out:
#            country        city province_state   region           subregion  \
# 170  United States  Huntsville        Alabama    South  East South Central
# 171  United States  Montgomery        Alabama    South  East South Central
# 172  United States   Anchorage         Alaska     West             Pacific
# 173  United States      Juneau         Alaska     West             Pacific
# 174  United States     Phoenix        Arizona     West            Mountain
# ..             ...         ...            ...      ...                 ...
# 248  United States     Olympia     Washington     West             Pacific
# 249  United States  Charleston  West Virginia    South      South Atlantic
# 250  United States   Milwaukee      Wisconsin  Midwest  East North Central
# 251  United States    Cheyenne        Wyoming     West            Mountain
# 252  United States  Charleston        Wyoming     West            Mountain
#
#     province_state_level
# 170                state
# ...

# %%
states = united_states_data_frame["province_state"].unique()
states.sort()
print(len(states))
states
# Out:
# 50
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia',
#        'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas',
#        'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts',
#        'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana',
#        'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico',
#        'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma',
#        'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina',
#        'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont',
#        'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming'],
#       dtype=object)

# %% [markdown]
# ## Vietnam

# %%
vietnam_data_frame = cities_data_frame[cities_data_frame["country"] == "Vietnam"]
vietnam_data_frame
# Out:
#      country           city province_state    region           subregion  \
# 253  Vietnam  Điện Biên Phủ      Điện Biên  Northern           Northwest
# 254  Vietnam       Hòa Bình       Hòa Bình  Northern           Northwest
# 255  Vietnam       Lai Châu       Lai Châu  Northern           Northwest
# 256  Vietnam        Lào Cai        Lào Cai  Northern           Northwest
# 257  Vietnam         Sơn La         Sơn La  Northern           Northwest
# ..       ...            ...            ...       ...                 ...
# 311  Vietnam      Sóc Trăng      Sóc Trăng  Southern  Mekong River Delta
# 312  Vietnam         Mỹ Tho     Tiền Giang  Southern  Mekong River Delta
# 313  Vietnam       Trà Vinh       Trà Vinh  Southern  Mekong River Delta
# 314  Vietnam      Vĩnh Long      Vĩnh Long  Southern  Mekong River Delta
# 315  Vietnam        Cần Thơ        Cần Thơ  Southern  Mekong River Delta
#
#     province_state_level
# 253             province
# 254             province
# ...

# %%
provinces = vietnam_data_frame["province_state"].unique()
provinces.sort()
print(len(provinces))
provinces
# Out:
# 63
# array(['An Giang', 'Bà Rịa-Vũng Tàu', 'Bình Dương', 'Bình Phước',
#        'Bình Thuận', 'Bình Định', 'Bạc Liêu', 'Bắc Giang', 'Bắc Kạn',
#        'Bắc Ninh', 'Bến Tre', 'Cao Bằng', 'Cà Mau', 'Cần Thơ', 'Gia Lai',
#        'Hà Giang', 'Hà Nam', 'Hà Nội', 'Hà Tĩnh', 'Hòa Bình', 'Hưng Yên',
#        'Hải Dương', 'Hải Phòng', 'Hậu Giang', 'Hồ Chí Minh', 'Khánh Hòa',
#        'Kiên Giang', 'Kon Tum', 'Lai Châu', 'Long An', 'Lào Cai',
#        'Lâm Đồng', 'Lạng Sơn', 'Nam Định', 'Nghệ An', 'Ninh Bình',
#        'Ninh Thuận', 'Phú Thọ', 'Phú Yên', 'Quảng Bình', 'Quảng Nam',
#        'Quảng Ngãi', 'Quảng Ninh', 'Quảng Trị', 'Sóc Trăng', 'Sơn La',
#        'Thanh Hóa', 'Thái Bình', 'Thái Nguyên', 'Thừa Thiên-Huế',
#        'Tiền Giang', 'Trà Vinh', 'Tuyên Quang', 'Tây Ninh', 'Vĩnh Long',
#        'Vĩnh Phúc', 'Yên Bái', 'Điện Biên', 'Đà Nẵng', 'Đắk Lắk',
#        'Đắk Nông', 'Đồng Nai', 'Đồng Tháp'], dtype=object)
