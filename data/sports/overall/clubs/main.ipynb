# %%
import pandas as pd

# %%
clubs_data_frame = pd.read_csv("./clubs.csv")
clubs_data_frame = clubs_data_frame.sort_values(by=["sport", "country"])
clubs_data_frame.to_csv("./clubs.csv", index=False)
clubs_data_frame
# Out:
#                 sport                       name moniker             city  \
# 0   american-football              Buffalo Bills     NaN     Orchard Park
# 1   american-football             Miami Dolphins     NaN    Miami Gardens
# 2   american-football       New England Patriots     NaN       Foxborough
# 3   american-football              New York Jets     NaN  East Rutherford
# 4   american-football           Baltimore Ravens     NaN        Baltimore
# ..                ...                        ...     ...              ...
# 60             futsal               Thái Sơn Nam     NaN      Hồ Chí Minh
# 61             futsal              Tân Hiệp Hưng     NaN      Hồ Chí Minh
# 62             futsal            VietFootball FC     NaN           Hà Nội
# 63             futsal                 Đà Nẵng FC     NaN          Đà Nẵng
# 64             futsal  Hưng Gia Khang Đắk Lắk FC     NaN          Đắk Lắk
#
#             state division conference        country              venue  \
# ...
