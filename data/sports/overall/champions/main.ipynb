# %%
import pandas as pd

# %%
champions_data_frame = pd.read_csv("./champions.csv")
champions_data_frame = champions_data_frame.sort_values(
    by=["sport", "competition", "season"]
)
champions_data_frame.to_csv("./champions.csv", index=False)
champions_data_frame
# Out:
#                   sport gender competition_tour competition_type competition  \
# 0     American Football   male              NaN              NaN         NFL
# 1     American Football   male              NaN              NaN         NFL
# 2     American Football   male              NaN              NaN         NFL
# 3     American Football   male              NaN              NaN         NFL
# 4     American Football   male              NaN              NaN         NFL
# ...                 ...    ...              ...              ...         ...
# 1610             Tennis    NaN       Grand Slam            grass   Wimbledon
# 1611             Tennis    NaN       Grand Slam            grass   Wimbledon
# 1612             Tennis    NaN       Grand Slam            grass   Wimbledon
# 1613             Tennis    NaN       Grand Slam            grass   Wimbledon
# 1614             Tennis    NaN       Grand Slam            grass   Wimbledon
#
# ...

# %% [markdown]
# ## Worlds

# %%
worlds_data_frame = champions_data_frame[
    champions_data_frame["competition"] == "Worlds"
]
worlds_data_frame
# Out:
#                   sport gender    competition_tour competition_type  \
# 1252  League of Legends    NaN  World Championship              NaN
# 1253  League of Legends    NaN  World Championship              NaN
# 1254  League of Legends    NaN  World Championship              NaN
# 1255  League of Legends    NaN  World Championship              NaN
# 1256  League of Legends    NaN  World Championship              NaN
# 1257  League of Legends    NaN  World Championship              NaN
# 1258  League of Legends    NaN  World Championship              NaN
# 1259  League of Legends    NaN  World Championship              NaN
# 1260  League of Legends    NaN  World Championship              NaN
# 1261  League of Legends    NaN  World Championship              NaN
# 1262  League of Legends    NaN  World Championship              NaN
# 1263  League of Legends    NaN  World Championship              NaN
# 1264  League of Legends    NaN  World Championship              NaN
#
# ...

# %%
champions = worlds_data_frame[["champion", "champion_conference"]].value_counts()
champions
# Out:
# champion         champion_conference
# T1               South Korea            4
# Samsung Galaxy   South Korea            2
# DRX              South Korea            1
# Dplus KIA        South Korea            1
# Edward Gaming    China                  1
# Fnatic           United Kingdom         1
# FunPlus Phoenix  China                  1
# Invictus Gaming  China                  1
# J Team           Taiwan                 1
# Name: count, dtype: int64

# %%
runners_up = worlds_data_frame[["runner_up", "runner_up_conference"]].value_counts()
runners_up
# Out:
# runner_up              runner_up_conference
# Royal Club             China                   2
# T1                     South Korea             2
# Weibo Gaming           China                   2
# DWG KIA                South Korea             1
# Fnatic                 United Kingdom          1
# G2 Esports             Germany                 1
# Hanwha Life Esports    South Korea             1
# OGN Entus              South Korea             1
# Samsung Galaxy         South Korea             1
# against All authority  France                  1
# Name: count, dtype: int64

# %%
finals = worlds_data_frame[["champion", "runner_up"]].value_counts()
finals
# Out:
# champion         runner_up
# DRX              T1                       1
# Dplus KIA        Weibo Gaming             1
# Edward Gaming    DWG KIA                  1
# Fnatic           against All authority    1
# FunPlus Phoenix  G2 Esports               1
# Invictus Gaming  Fnatic                   1
# J Team           OGN Entus                1
# Samsung Galaxy   Royal Club               1
#                  T1                       1
# T1               Hanwha Life Esports      1
#                  Royal Club               1
#                  Samsung Galaxy           1
#                  Weibo Gaming             1
# Name: count, dtype: int64

# %% [markdown]
# ## The International

# %%
international_data_frame = champions_data_frame[
    champions_data_frame["competition"] == "The International"
]
international_data_frame
# Out:
#                                   sport gender    competition_tour  \
# 435  Defense of the Ancients 2 (DotA 2)    NaN  World Championship
# 436  Defense of the Ancients 2 (DotA 2)    NaN  World Championship
# 437  Defense of the Ancients 2 (DotA 2)    NaN  World Championship
# 438  Defense of the Ancients 2 (DotA 2)    NaN  World Championship
# 439  Defense of the Ancients 2 (DotA 2)    NaN  World Championship
# 440  Defense of the Ancients 2 (DotA 2)    NaN  World Championship
# 441  Defense of the Ancients 2 (DotA 2)    NaN  World Championship
# 442  Defense of the Ancients 2 (DotA 2)    NaN  World Championship
# 443  Defense of the Ancients 2 (DotA 2)    NaN  World Championship
# 444  Defense of the Ancients 2 (DotA 2)    NaN  World Championship
# 445  Defense of the Ancients 2 (DotA 2)    NaN  World Championship
# 446  Defense of the Ancients 2 (DotA 2)    NaN  World Championship
#
#     competition_type        competition competition_area season  month  \
# ...

# %% [markdown]
# ## FIFAe World Cup

# %%
fifa_data_frame = champions_data_frame[
    champions_data_frame["competition"] == "FIFAe World Cup"
]
fifa_data_frame
# Out:
#     sport gender    competition_tour competition_type      competition  \
# 447  FIFA    NaN  World Championship              NaN  FIFAe World Cup
# 448  FIFA    NaN  World Championship              NaN  FIFAe World Cup
# 449  FIFA    NaN  World Championship              NaN  FIFAe World Cup
# 450  FIFA    NaN  World Championship              NaN  FIFAe World Cup
# 451  FIFA    NaN  World Championship              NaN  FIFAe World Cup
# 452  FIFA    NaN  World Championship              NaN  FIFAe World Cup
# 453  FIFA    NaN  World Championship              NaN  FIFAe World Cup
# 454  FIFA    NaN  World Championship              NaN  FIFAe World Cup
# 455  FIFA    NaN  World Championship              NaN  FIFAe World Cup
# 456  FIFA    NaN  World Championship              NaN  FIFAe World Cup
# 457  FIFA    NaN  World Championship              NaN  FIFAe World Cup
# 458  FIFA    NaN  World Championship              NaN  FIFAe World Cup
# ...

# %%
champions = fifa_data_frame[["champion", "champion_conference"]].value_counts()
champions
# Out:
# champion                   champion_conference
# Alfonso Ramos              Spain                  2
# Bruce Grannec              France                 2
# Mosaad Al Dossary          Saudi Arabia           2
# Abdulaziz Alshehri         Saudi Arabia           1
# Andries Smit               Netherlands            1
# August Rosenmeier          Denmark                1
# Chris Bullard              England                1
# Francisco Cruz             Portugal               1
# Manuel Bachoore            Netherlands            1
# Mohamad Al-Bacha           Denmark                1
# Mohammed Harkous           Germany                1
# Nenad Stojkovic            Serbia                 1
# Nicolas Villalba           Argentina              1
# Spencer Ealing             England                1
# Thiago Carrico de Azevedo  Brazil                 1
# Umut Gültekin              Germany                1
# Name: count, dtype: int64

# %%
runners_up = fifa_data_frame[["runner_up", "runner_up_conference"]].value_counts()
runners_up
# Out:
# runner_up               runner_up_conference
# Nicolas Villalba        Argentina               2
# Andrei Torres Vivero    Mexico                  1
# Ayhan Altundag          Germany                 1
# Stefano Pinna           Belgium                 1
# Sean Allen              England                 1
# Ruben Morales Zerecero  Mexico                  1
# Mosaad Aldossary        Saudi Arabia            1
# Mohammed Harkous        Germany                 1
# Michael Ribeiro         United States           1
# Matija Biljeskovic      United States           1
# Mark Zakhary            Australia               1
# Kai Wollin              Germany                 1
# Julien Dassonville      France                  1
# Javier Munoz            Columbia                1
# Gábor Mokos             Hungary                 1
# David Bytheway          England                 1
# Bruce Grannec           France                  1
# Wolfgang Meier          Austria                 1
# ...
